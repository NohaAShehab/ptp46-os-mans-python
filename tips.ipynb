# %%
size = input("Please enter size of pryamid ")
if size.isdigit():
    size = int(size)
    for i in range(1, size+1):
        print(i*"*")

"""
    *
   **
  ***

"""
# Out:
# *
# **
# ***

# %%
# no of spaces  total -i
size = input("Please enter size of pryamid ")
if size.isdigit():
    size = int(size)
    for i in range(1, size+1):
        spaces  = size - i
        print(spaces*" " + i*"*")
# Out:
#    *
#   **
#  ***
# ****

# %% [markdown]
# # for else

# %%
for i in range(3):
    password = input("please enter password ")
    if password =='abc':
        print('Login successful')
        break
    elif i < 2:
        print("----- please enter password -----")

# the account will be locked only if ??? the loop isn't broken
print("------ the account is locked")

# %%
for i in range(3):
    password = input("please enter password ")
    if password =='abc':
        print('Login successful')
        break
    elif i < 2:
        print("----- please enter password -----")
else:
    print("---- the account is locked")
    print("------ this block will be executed if the loop completed successfully ")
# Out:
# ----- please enter password -----
# ----- please enter password -----
# ---- the account is locked
# ------ this block will be executed if the loop completed successfully

# %%
for i in range(3):
    password = input("please enter password ")
    if password =='abc':
        print('Login successful')
        break
    elif i < 2:
        print("----- please enter password -----")
else:
    print("---- the account is locked")
    print("------ this block will be executed if the loop completed successfully ")
# Out:
# ----- please enter password -----
# ----- please enter password -----
# Login successful

# %%
for i in range(3):
    password = input("please enter password ")
    if password =='abc':
        print('Login successful')
        break
    elif i < 2:
        print("----- please enter password -----")
else:
    print("---- the account is locked")
    print("------ this block will be executed if the loop completed successfully ")
# Out:
# ----- please enter password -----
# Login successful

# %%
"""
name = 'iti'
if (name == 'iti'){}  # syntax --> development phase only not production ?
"""

name = 'iti'
if name == 'iti':

print("------")
# Out:
#   Cell In[9], line 9
#     print("------")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 7

# %%
name = 'iti'
"""
pass is a null operation — when it is executed, nothing happens. It is useful as a placeholder when a statement is required syntactically, but no code needs to be executed
"""
if name == 'iti':
    pass

print("------")
