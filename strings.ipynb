# %% [markdown]
# # logical operators

# %%
print("iti" and "open source")
# Out:
# open source

# %%
print(bool('iti'))
# Out:
# True

# %%
res = '' and "noha"
if res:
    print("hi")
else:
    print("bye")
# Out:
# bye

# %%
print("iti" or "opensource")
# Out:
# iti
